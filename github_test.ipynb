# %%
print("github")
# Out:
# github

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/natsutosisumita/Downloads/Pokemon.csv")

# %%
(df[df["type1"] == "Normal"])
# Out:
#      number          name   type1   type2  total   hp  attack  defense  \
# 24       16        Pidgey  Normal  Flying    251   40      45       40
# 25       17     Pidgeotto  Normal  Flying    349   63      60       55
# 26       18       Pidgeot  Normal  Flying    479   83      80       75
# 27       18  Mega Pidgeot  Normal  Flying    579   83      80       80
# 28       19       Rattata  Normal     NaN    253   30      56       35
# ..      ...           ...     ...     ...    ...  ...     ...      ...
# 919     780        Drampa  Normal  Dragon    485   78      60       85
# 965     819       Skwovet  Normal     NaN    275   70      55       55
# 966     820      Greedent  Normal     NaN    460  120      95       95
# 979     831        Wooloo  Normal     NaN    270   42      40       55
# 980     832       Dubwool  Normal     NaN    490   72      80      100
#
#      sp_attack  sp_defense  speed  generation  legendary
# 24          35          35     56           1      False
# ...

# %%
df["sum"]=df["hp"]+df["attack"]+df["defense"]+df["sp_attack"]+df["sp_defense"]+df["speed"]
df
# Out:
#       number                  name    type1   type2  total   hp  attack  \
# 0          1             Bulbasaur    Grass  Poison    318   45      49
# 1          2               Ivysaur    Grass  Poison    405   60      62
# 2          3              Venusaur    Grass  Poison    525   80      82
# 3          3         Mega Venusaur    Grass  Poison    625   80     100
# 4          3   Gigantamax Venusaur    Grass  Poison    525   80      82
# ...      ...                   ...      ...     ...    ...  ...     ...
# 1067     896             Glastrier      Ice     NaN    580  100     145
# 1068     897             Spectrier    Ghost     NaN    580  100      65
# 1069     898               Calyrex  Psychic   Grass    500  100      80
# 1070     898     Ice Rider Calyrex  Psychic     Ice    680  100     165
# 1071     898  Shadow Rider Calyrex  Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary  sum
# ...

# %%
df_600=(df[df["sum"]==600])

# %%
df_600nl=(df_600[(df_600["legendary"]==False) & (~df_600["name"].str.contains("Mega"))])
df_600nl
# Out:
#       number       name   type1     type2  total   hp  attack  defense  \
# 202      149  Dragonite  Dragon    Flying    600   91     134       95
# 310      248  Tyranitar    Rock      Dark    600  100     134      110
# 453      373  Salamence  Dragon    Flying    600   95     135       80
# 457      376  Metagross   Steel   Psychic    600   80     135      130
# 538      445   Garchomp  Dragon    Ground    600  108     130       95
# 747      635  Hydreigon    Dark    Dragon    600   92     105       90
# 828      706     Goodra  Dragon       NaN    600   90     100       70
# 923      784    Kommo-o  Dragon  Fighting    600   75     110      125
# 1051     887  Dragapult  Dragon     Ghost    600   88     120       75
#
#       sp_attack  sp_defense  speed  generation  legendary  sum
# 202         100         100     80           1      False  600
# 310          95         100     61           2      False  600
# 453         110          80    100           3      False  600
# ...
